# %% [markdown]
# <h3 align="center">SA4110 MACHINE LEARNING APPLICATION DEVELOPMENT</h3>
# <h4 align="center">CA - TEAM PROJECT - IMAGE CLASSIFIER</h4>
# <hr>
#
# <div class="alert alert-block alert-info">
# <b><u>Tasks:</u></b>
# <ol>
# <li>Create an Image Classifier (CNN model) to classify images of fruits correctly.</li>
# <li>A Fruits Dataset is provided that consists of these 3 Classes: -</li>
#     <ul>
#     <li>Apple</li>
#     <li>Banana</li>
#     <li>Orange</li>
#     </ul>
# <li>Use the Images in train.zip and test.zip to Train and Test your Image Classifier.</li>
# <li>Document your experiments and results in improving your model’s accuracy.</li>
# <li>The Following Activities can Improve your Model’s Accuracy: -</li>
#     <ul>
#     <li>Balance out the Number of Samples in Each Class</li>
#     <li>Correct any mis-labelling in any of the 3 Classes</li>
#     <li>Image Augmentation to Generate more Data </li>
#     </ul>
# <li>Use Matplotlib to Generate any Plots that can Help the Reader understand your Work Better.</li>
# </ol></div>

# %%
### Step 1: Import the Necessary Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

import os
os.environ["KERAS_BACKEND"] = "torch"

import torch
import keras

from sklearn.metrics import confusion_matrix, classification_report
from pathlib import Path
from PIL import Image
from IPython.display import display, HTML

# %%
### Step 2.1: Load the Training Datasets

# Define the Path Directory to 'train' directory
img_train_dir = Path.cwd().parents[1] / "train"

""" Generate a Classification Labels associated with the Respective Fruit Classes based on FileName """
# Initialize the Required Parameters for the Classification Label
img_T_fileNames = []
img_T_classLabel = []

for img_path in img_train_dir.glob("*.jpg"):
    try:
        img_T_fileNames.append(img_path.name)
        img_T_classLabel.append(img_path.name.strip().split('_')[0])
    except Exception as e:
        print(f"Unable to Read {img_path.name}: {e}")

class_train_df = pd.DataFrame({
    'fileName' : img_T_fileNames,
    'classLabel' : img_T_classLabel
})

display(HTML("<h3>Display (10) Random Sample of the Class Label DataFrame:</h3>"))
display(class_train_df.sample(10)
        .style
        .highlight_null(color='lightcoral')
        .set_properties(**{'color':'white'})
        .set_table_styles([
            {'selector':'tr:nth-child(even)', 'props': [('background-color', '#708090')]},
            {'selector':'th', 'props':[('text-align', 'center')]},
            {'selector':'tr:nth', 'props':[('text-align', 'center')]}
        ]))

# Calculting the Images Median Width and Height to Determine the Target Size
img_T_widths = []
img_T_heights = []

for img_path in img_train_dir.rglob("*.jpg"):
    try:
        with Image.open(img_path) as img:
            img_T_widths.append(img.size[0])
            img_T_heights.append(img.size[1])
    except Exception as e:
        print(f"Unable to Read {img_path.name}: {e}")

if img_T_widths and img_T_heights:
    img_T_widths_median = statistics.median(img_T_widths)
    img_T_heights_median = statistics.median(img_T_heights)

    print(f"Total No. of Images Evaluated: {len(img_T_widths)}")
    print(f"Image Median Widths: {img_T_widths_median}")
    print(f"Image Median Heights: {img_T_heights_median}")
else:
    print(f"No .jpg Images found in the Specified Directory.")
# Out:
# <h3>Display (10) Random Sample of the Class Label DataFrame:</h3>
# <style type="text/css">
# #T_594ad tr:nth-child(even) {
#   background-color: #708090;
# }
# #T_594ad th {
#   text-align: center;
# }
# #T_594ad tr:nth {
#   text-align: center;
# }
# #T_594ad_row0_col0, #T_594ad_row0_col1, #T_594ad_row1_col0, #T_594ad_row1_col1, #T_594ad_row2_col0, #T_594ad_row2_col1, #T_594ad_row3_col0, #T_594ad_row3_col1, #T_594ad_row4_col0, #T_594ad_row4_col1, #T_594ad_row5_col0, #T_594ad_row5_col1, #T_594ad_row6_col0, #T_594ad_row6_col1, #T_594ad_row7_col0, #T_594ad_row7_col1, #T_594ad_row8_col0, #T_594ad_row8_col1, #T_594ad_row9_col0, #T_594ad_row9_col1 {
#   color: white;
# }
# </style>
# <table id="T_594ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_594ad_level0_col0" class="col_heading level0 col0" >fileName</th>
#       <th id="T_594ad_level0_col1" class="col_heading level0 col1" >classLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_594ad_level0_row0" class="row_heading level0 row0" >159</th>
#       <td id="T_594ad_row0_col0" class="data row0 col0" >orange_2.jpg</td>
#       <td id="T_594ad_row0_col1" class="data row0 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row1" class="row_heading level0 row1" >126</th>
#       <td id="T_594ad_row1_col0" class="data row1 col0" >banana_59.jpg</td>
#       <td id="T_594ad_row1_col1" class="data row1 col1" >banana</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row2" class="row_heading level0 row2" >61</th>
#       <td id="T_594ad_row2_col0" class="data row2 col0" >apple_66.jpg</td>
#       <td id="T_594ad_row2_col1" class="data row2 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row3" class="row_heading level0 row3" >17</th>
#       <td id="T_594ad_row3_col0" class="data row3 col0" >apple_25.jpg</td>
#       <td id="T_594ad_row3_col1" class="data row3 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row4" class="row_heading level0 row4" >175</th>
#       <td id="T_594ad_row4_col0" class="data row4 col0" >orange_34.jpg</td>
#       <td id="T_594ad_row4_col1" class="data row4 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row5" class="row_heading level0 row5" >160</th>
#       <td id="T_594ad_row5_col0" class="data row5 col0" >orange_20.jpg</td>
#       <td id="T_594ad_row5_col1" class="data row5 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row6" class="row_heading level0 row6" >51</th>
#       <td id="T_594ad_row6_col0" class="data row6 col0" >apple_57.jpg</td>
#       <td id="T_594ad_row6_col1" class="data row6 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row7" class="row_heading level0 row7" >33</th>
#       <td id="T_594ad_row7_col0" class="data row7 col0" >apple_40.jpg</td>
#       <td id="T_594ad_row7_col1" class="data row7 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_594ad_row8_col0" class="data row8 col0" >apple_29.jpg</td>
#       <td id="T_594ad_row8_col1" class="data row8 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_594ad_level0_row9" class="row_heading level0 row9" >15</th>
#       <td id="T_594ad_row9_col0" class="data row9 col0" >apple_23.jpg</td>
#       <td id="T_594ad_row9_col1" class="data row9 col1" >apple</td>
#     </tr>
#   </tbody>
# </table>
# Total No. of Images Evaluated: 220
# Image Median Widths: 640.0
# Image Median Heights: 481.5

# %%
### Step 2.2: Load the Testing Datasets

# Define the Path Directory to 'train' directory
img_train_dir = Path.cwd().parents[1] / "test"

""" Generate a Classification Labels associated with the Respective Fruit Classes based on FileName """
# Initialize the Required Parameters for the Classification Label
img_t_fileNames = []
img_t_classLabel = []

for img_path in img_train_dir.glob("*.jpg"):
    try:
        img_t_fileNames.append(img_path.name)
        img_t_classLabel.append(img_path.name.strip().split('_')[0])
    except Exception as e:
        print(f"Unable to Read {img_path.name}: {e}")

class_test_df = pd.DataFrame({
    'fileName' : img_t_fileNames,
    'classLabel' : img_t_classLabel
})

display(HTML("<h3>Display (10) Random Sample of the Class Label DataFrame:</h3>"))
display(class_test_df.sample(10)
        .style
        .highlight_null(color='lightcoral')
        .set_properties(**{'color':'white'})
        .set_table_styles([
            {'selector':'tr:nth-child(even)', 'props': [('background-color', '#708090')]},
            {'selector':'th', 'props':[('text-align', 'center')]},
            {'selector':'tr:nth', 'props':[('text-align', 'center')]}
        ]))

# Calculting the Images Median Width and Height to Determine the Target Size
img_t_widths = []
img_t_heights = []

for img_path in img_train_dir.rglob("*.jpg"):
    try:
        with Image.open(img_path) as img:
            img_t_widths.append(img.size[0])
            img_t_heights.append(img.size[1])
    except Exception as e:
        print(f"Unable to Read {img_path.name}: {e}")

if img_t_widths and img_t_heights:
    img_t_widths_median = statistics.median(img_t_widths)
    img_t_heights_median = statistics.median(img_t_heights)

    print(f"Total No. of Images Evaluated: {len(img_t_widths)}")
    print(f"Image Median Widths: {img_t_widths_median}")
    print(f"Image Median Heights: {img_t_heights_median}")
else:
    print(f"No .jpg Images found in the Specified Directory.")
# Out:
# <h3>Display (10) Random Sample of the Class Label DataFrame:</h3>
# <style type="text/css">
# #T_0b22d tr:nth-child(even) {
#   background-color: #708090;
# }
# #T_0b22d th {
#   text-align: center;
# }
# #T_0b22d tr:nth {
#   text-align: center;
# }
# #T_0b22d_row0_col0, #T_0b22d_row0_col1, #T_0b22d_row1_col0, #T_0b22d_row1_col1, #T_0b22d_row2_col0, #T_0b22d_row2_col1, #T_0b22d_row3_col0, #T_0b22d_row3_col1, #T_0b22d_row4_col0, #T_0b22d_row4_col1, #T_0b22d_row5_col0, #T_0b22d_row5_col1, #T_0b22d_row6_col0, #T_0b22d_row6_col1, #T_0b22d_row7_col0, #T_0b22d_row7_col1, #T_0b22d_row8_col0, #T_0b22d_row8_col1, #T_0b22d_row9_col0, #T_0b22d_row9_col1 {
#   color: white;
# }
# </style>
# <table id="T_0b22d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b22d_level0_col0" class="col_heading level0 col0" >fileName</th>
#       <th id="T_0b22d_level0_col1" class="col_heading level0 col1" >classLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b22d_level0_row0" class="row_heading level0 row0" >51</th>
#       <td id="T_0b22d_row0_col0" class="data row0 col0" >orange_92.jpg</td>
#       <td id="T_0b22d_row0_col1" class="data row0 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_0b22d_row1_col0" class="data row1 col0" >apple_86.jpg</td>
#       <td id="T_0b22d_row1_col1" class="data row1 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row2" class="row_heading level0 row2" >39</th>
#       <td id="T_0b22d_row2_col0" class="data row2 col0" >orange_79.jpg</td>
#       <td id="T_0b22d_row2_col1" class="data row2 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row3" class="row_heading level0 row3" >37</th>
#       <td id="T_0b22d_row3_col0" class="data row3 col0" >orange_77.jpg</td>
#       <td id="T_0b22d_row3_col1" class="data row3 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_0b22d_row4_col0" class="data row4 col0" >apple_85.jpg</td>
#       <td id="T_0b22d_row4_col1" class="data row4 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row5" class="row_heading level0 row5" >42</th>
#       <td id="T_0b22d_row5_col0" class="data row5 col0" >orange_82.jpg</td>
#       <td id="T_0b22d_row5_col1" class="data row5 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_0b22d_row6_col0" class="data row6 col0" >apple_87.jpg</td>
#       <td id="T_0b22d_row6_col1" class="data row6 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_0b22d_row7_col0" class="data row7 col0" >apple_79.jpg</td>
#       <td id="T_0b22d_row7_col1" class="data row7 col1" >apple</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row8" class="row_heading level0 row8" >54</th>
#       <td id="T_0b22d_row8_col0" class="data row8 col0" >orange_95.jpg</td>
#       <td id="T_0b22d_row8_col1" class="data row8 col1" >orange</td>
#     </tr>
#     <tr>
#       <th id="T_0b22d_level0_row9" class="row_heading level0 row9" >19</th>
#       <td id="T_0b22d_row9_col0" class="data row9 col0" >banana_77.jpg</td>
#       <td id="T_0b22d_row9_col1" class="data row9 col1" >banana</td>
#     </tr>
#   </tbody>
# </table>
# Total No. of Images Evaluated: 55
# Image Median Widths: 650
# Image Median Heights: 500
