# %%
# About this model

# epoch = 30 (change from epoch = 20 of 00-00-template-CNN, but no change from 00-01-template-CNN)
# batch size = 16
# learning_rate=0.001 (default rate)
# RandAugment = 0.4
# Main adjustment 1: Add Dropout layer of 30%
# Main adjustment 2: Increase epoch = 50, previously 30
# val_accuracy maxes at 0.9773 at epoch 25, 3 epochs at least 0.9545

# %%
# =========================================
# 1. Import libraries
# =========================================

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

import os
from pathlib import Path

# 1. Set a master seed number
SEED = 42

# 2. Force Python and NumPy to use the seed
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# 3. Force TensorFlow / Keras to use the seed for weight initialization
tf.random.set_seed(SEED)

# 4. Optional: Force TensorFlow to operate deterministically
# Warning: This can slightly slow down your training speed, but ensures bit-for-bit replication
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
# check if all images have the same aspect ratio. Gemini recommends that all the images
# loaded into the neural network should have the same dimensions because the input layer
# will have a fixed number of input weights


from PIL import Image

# 1. Define your folder path
notebook_dir = Path.cwd()
train_image_folder = notebook_dir.parent / "train" / "train"

# 2. Collect all valid image paths
all_files = os.listdir(train_image_folder)
train_image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# 3. Scan dimensions and compute aspect ratios
records = []

for file in train_image_files:
    file_path = os.path.join(train_image_folder, file)
    try:
        with Image.open(file_path) as img:
            width, height = img.size
            # Aspect ratio is width divided by height
            aspect_ratio = width / height
            
            records.append({
                'filename': file,
                'width': width,
                'height': height,
                'aspect_ratio': round(aspect_ratio, 4)
            })
    except Exception as e:
        print(f"Skipping damaged or unreadable file {file}: {e}")

# 4. Convert records into a scannable DataFrame
ratio_df = pd.DataFrame(records)

# Display the first few rows of your new summary table
print("--- Aspect Ratio Dataframe (Preview) ---")
print(ratio_df.head())
print("\n" + "="*40 + "\n")

# 5. Programmatically verify if all images are squares
# A perfect square has an aspect ratio of exactly 1.0
all_squares = (ratio_df['aspect_ratio'] == 1.0).all()

if all_squares:
    print("All images in the folder are squares.")
else:
    # Identify exactly which files are breaking the rule
    non_squares = ratio_df[ratio_df['aspect_ratio'] != 1.0]
    print(f"{len(non_squares)} images are not squares.")
    print("\nNon-square images:")
    print(non_squares[['filename', 'width', 'height', 'aspect_ratio']])
# Out:
# --- Aspect Ratio Dataframe (Preview) ---
#         filename  width  height  aspect_ratio
# 0   apple_75.jpg    290     290        1.0000
# 1   apple_61.jpg    500     500        1.0000
# 2   apple_49.jpg    271     300        0.9033
# 3   orange_3.jpg    250     250        1.0000
# 4  orange_28.jpg    320     320        1.0000
#
# ========================================
#
# 179 images are not squares.
#
# Non-square images:
#           filename  width  height  aspect_ratio
# 2     apple_49.jpg    271     300        0.9033
# 5    banana_50.jpg    620     413        1.5012
# 6    orange_14.jpg    300     293        1.0239
# 7    banana_44.jpg    680     450        1.5111
# 8    banana_45.jpg    724     780        0.9282
# ..             ...    ...     ...           ...
# 215  banana_75.jpg    581     374        1.5535
# 216  orange_31.jpg   1300    1177        1.1045
# 217    apple_3.jpg   1000     708        1.4124
# 218   apple_44.jpg    337     335        1.0060
# 219   apple_50.jpg    300     227        1.3216
#
# [179 rows x 4 columns]

# %%
# split training data into training and validation, perform one hot encoding

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# # 1. Re-verify files and create absolute paths
# all_files = os.listdir(image_folder)
# image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

labels = [file.split('_')[0] for file in train_image_files]
abs_paths = [os.path.join(train_image_folder, f) for f in train_image_files]

df = pd.DataFrame({
    'filepath': abs_paths,
    'label': labels
})

# 2. Stratified Split (80% Train, 20% Validation)
# We stratify directly on the text 'label' ('apple', 'banana', etc.)
train_df, val_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    stratify=df['label']
)

# 3. ONE-HOT ENCODING WITH SKLEARNER
# sparse_output=False ensures we get a normal NumPy array instead of a matrix format
encoder = OneHotEncoder(sparse_output=False)

# scikit-learn expects a 2D array, so we use [['label']] instead of ['label']
# We fit the encoder ONLY on the training data, then transform both sets
train_labels_one_hot = encoder.fit_transform(train_df[['label']])
val_labels_one_hot = encoder.transform(val_df[['label']])

print("OneHotEncoder implementation successful!")
print(f"Categories discovered by encoder: {encoder.categories_[0]}")
print(f"Sample encoded row shape: {train_labels_one_hot[0]}") # Displays [1. 0. 0.]
# Out:
# OneHotEncoder implementation successful!
# Categories discovered by encoder: ['apple' 'banana' 'orange']
# Sample encoded row shape: [0. 0. 1.]

# %%
# perform letterboxing on images. when an image is a long rectangle, it is padded with 
# black pixels then cropped to a square. 
# all images will be 150 x 150

import numpy as np
from PIL import Image, ImageOps

# Setting value to 150 means images will be resized and cropped to 150 x 150
IMG_SIZE = 150  

def process_single_letterbox(filepath):
    """Loads a raw image file, letterboxes it to a square, and normalizes pixels."""
    with Image.open(filepath) as img:
        img = img.convert('RGB') # Ensure it has 3 color channels (Red, Green, Blue)
        
        # 1. Shrink the image so its longest side is exactly IMG_SIZE pixels
        img.thumbnail((IMG_SIZE, IMG_SIZE), Image.Resampling.LANCZOS)
        
        # 2. Calculate how many black border pixels to add to fill out the square
        delta_w = IMG_SIZE - img.size[0]
        delta_h = IMG_SIZE - img.size[1]
        
        # Divide the padding evenly between top/bottom and left/right edges
        padding = (delta_w // 2, delta_h // 2, delta_w - (delta_w // 2), delta_h - (delta_h // 2))
        
        # Apply the borders
        letterboxed_img = ImageOps.expand(img, padding, fill=(0, 0, 0))
        
        # 3. Convert to a standard NumPy matrix and rescale pixel values to [0, 1] range
        return np.array(letterboxed_img, dtype=np.float32) / 255.0

# Run the fixed functions on your datasets
X_train = np.array([process_single_letterbox(path) for path in train_df['filepath']])
X_val = np.array([process_single_letterbox(path) for path in val_df['filepath']])

y_train = train_labels_one_hot
y_val = val_labels_one_hot

print(f"X_train array shape: {X_train.shape}")  # Will cleanly output: (num_images, 150, 150, 3)
print(f"y_train array shape: {y_train.shape}")  # Will cleanly output: (num_images, 3)
# Out:
# /Users/kwokheng/ml-tensorflow/.venv/lib/python3.13/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# X_train array shape: (176, 150, 150, 3)
# y_train array shape: (176, 3)

# %%
# build the CNN

from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # 1. Input Layer: Matches our letterboxed dimensions
    keras.Input(shape=(150, 150, 3)),
    
    # 2. Augmentation Layer: Automatically active ONLY during training (.fit)
    # It scales its operations automatically because our input is already [0, 1]
    layers.RandAugment(num_ops=2, factor=0.4, value_range=(0.0, 1.0)),
    
    # 3. Conv1 Layer Block
    layers.Conv2D(filters=16, kernel_size=(3, 3), padding="same", activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),
    
    # 4. Conv2 Layer Block
    layers.Conv2D(filters=32, kernel_size=(3, 3), padding="same", activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),

    # Add Dropout layer: Disable 30% of neurons
    layers.Dropout(0.3), 
        
    # 5. Classifier Head
    layers.Flatten(),
    layers.Dense(units=128, activation="relu"),
    layers.Dense(units=3, activation="softmax") # 3 units for Apples, Bananas, Oranges
])

# %%
# Compile using categorical_crossentropy to match OneHotEncoder outputs!
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             keras.metrics.Precision(name='precision'), # Tracks false positives
             keras.metrics.Recall(name='recall')]        # Tracks false negatives
)
     
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rand_augment (RandAugment)      │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 150, 150, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 43808)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     5,607,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,613,027 (21.41 MB)
#  Trainable params: 5,613,027 (21.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# # apply early_stop to get best epoch for validation accuracy

# early_stop = keras.callbacks.EarlyStopping(
#     monitor='val_accuracy',     # Watch validation accuracy
#     mode='max',                 # We want accuracy to go up
#     patience=4,                 # If it doesn't beat 93.18% in 4 epochs, stop
#     restore_best_weights=True   # Rewind to the absolute best epoch (Epoch 12)
# )

# %%
# train the model
history = model.fit(
    X_train, 
    y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=16,
    # callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.3295 - loss: 2.4841 - precision: 0.3636 - recall: 0.2500 - val_accuracy: 0.4773 - val_loss: 1.0381 - val_precision: 0.4500 - val_recall: 0.2045
# Epoch 2/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779529398.262665 3917416 node_def_util.cc:682] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.3920 - loss: 1.0894 - precision: 0.3939 - recall: 0.0739 - val_accuracy: 0.5455 - val_loss: 0.9634 - val_precision: 0.6875 - val_recall: 0.2500
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.5511 - loss: 0.9862 - precision: 0.7097 - recall: 0.1250 - val_accuracy: 0.6818 - val_loss: 0.8633 - val_precision: 0.8095 - val_recall: 0.3864
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.5284 - loss: 0.9939 - precision: 0.7143 - recall: 0.1989 - val_accuracy: 0.7727 - val_loss: 0.7574 - val_precision: 0.9167 - val_recall: 0.7500
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.6705 - loss: 0.8375 - precision: 0.8202 - recall: 0.4148 - val_accuracy: 0.8182 - val_loss: 0.5861 - val_precision: 0.8947 - val_recall: 0.7727
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.6136 - loss: 0.8330 - precision: 0.7765 - recall: 0.3750 - val_accuracy: 0.8182 - val_loss: 0.5023 - val_precision: 0.8293 - val_recall: 0.7727
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.7670 - loss: 0.6148 - precision: 0.8296 - recall: 0.6364 - val_accuracy: 0.7955 - val_loss: 0.4053 - val_precision: 0.8462 - val_recall: 0.7500
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7670 - loss: 0.5718 - precision: 0.8182 - recall: 0.7159 - val_accuracy: 0.7500 - val_loss: 0.5260 - val_precision: 0.7674 - val_recall: 0.7500
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8182 - loss: 0.4758 - precision: 0.8571 - recall: 0.7841 - val_accuracy: 0.8864 - val_loss: 0.2364 - val_precision: 0.9070 - val_recall: 0.8864
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7727 - loss: 0.5309 - precision: 0.7759 - recall: 0.7670 - val_accuracy: 0.8409 - val_loss: 0.4769 - val_precision: 0.8409 - val_recall: 0.8409
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.7670 - loss: 0.5632 - precision: 0.8425 - recall: 0.6989 - val_accuracy: 0.7727 - val_loss: 0.4261 - val_precision: 0.7907 - val_recall: 0.7727
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8750 - loss: 0.3578 - precision: 0.8976 - recall: 0.8466 - val_accuracy: 0.9318 - val_loss: 0.2436 - val_precision: 0.9302 - val_recall: 0.9091
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7159 - loss: 0.6359 - precision: 0.7466 - recall: 0.6193 - val_accuracy: 0.7727 - val_loss: 0.5258 - val_precision: 0.7727 - val_recall: 0.7727
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8750 - loss: 0.4056 - precision: 0.8970 - recall: 0.8409 - val_accuracy: 0.7955 - val_loss: 0.5293 - val_precision: 0.7955 - val_recall: 0.7955
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.6761 - loss: 0.8144 - precision: 0.7134 - recall: 0.6364 - val_accuracy: 0.7273 - val_loss: 0.8163 - val_precision: 0.7381 - val_recall: 0.7045
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.6364 - loss: 0.6879 - precision: 0.7574 - recall: 0.5852 - val_accuracy: 0.8182 - val_loss: 0.3333 - val_precision: 0.9211 - val_recall: 0.7955
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7500 - loss: 0.5443 - precision: 0.7838 - recall: 0.6591 - val_accuracy: 0.8409 - val_loss: 0.3780 - val_precision: 0.8409 - val_recall: 0.8409
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.7443 - loss: 0.5747 - precision: 0.8227 - recall: 0.6591 - val_accuracy: 0.8636 - val_loss: 0.2929 - val_precision: 0.8605 - val_recall: 0.8409
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.8466 - loss: 0.4152 - precision: 0.8625 - recall: 0.7841 - val_accuracy: 0.9545 - val_loss: 0.1689 - val_precision: 0.9762 - val_recall: 0.9318
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7670 - loss: 0.4576 - precision: 0.7964 - recall: 0.7557 - val_accuracy: 0.8182 - val_loss: 0.5128 - val_precision: 0.8182 - val_recall: 0.8182
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.8182 - loss: 0.4229 - precision: 0.8304 - recall: 0.8068 - val_accuracy: 0.7727 - val_loss: 0.6281 - val_precision: 0.7727 - val_recall: 0.7727
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.7784 - loss: 0.5260 - precision: 0.7929 - recall: 0.7614 - val_accuracy: 0.9545 - val_loss: 0.2131 - val_precision: 0.9535 - val_recall: 0.9318
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.8920 - loss: 0.2930 - precision: 0.9042 - recall: 0.8580 - val_accuracy: 0.8182 - val_loss: 0.3593 - val_precision: 0.8372 - val_recall: 0.8182
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.8011 - loss: 0.5125 - precision: 0.8182 - recall: 0.7670 - val_accuracy: 0.7727 - val_loss: 0.4864 - val_precision: 0.7727 - val_recall: 0.7727
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.8466 - loss: 0.4344 - precision: 0.8690 - recall: 0.8295 - val_accuracy: 0.9773 - val_loss: 0.1718 - val_precision: 0.9767 - val_recall: 0.9545
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9034 - loss: 0.2985 - precision: 0.9217 - recall: 0.8693 - val_accuracy: 0.8182 - val_loss: 0.3893 - val_precision: 0.8571 - val_recall: 0.8182
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.8523 - loss: 0.3797 - precision: 0.8795 - recall: 0.8295 - val_accuracy: 0.8864 - val_loss: 0.3298 - val_precision: 0.8864 - val_recall: 0.8864
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.8920 - loss: 0.3203 - precision: 0.8960 - recall: 0.8807 - val_accuracy: 0.8182 - val_loss: 0.4360 - val_precision: 0.8182 - val_recall: 0.8182
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8977 - loss: 0.3805 - precision: 0.9118 - recall: 0.8807 - val_accuracy: 0.8636 - val_loss: 0.3068 - val_precision: 0.8636 - val_recall: 0.8636
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8693 - loss: 0.3548 - precision: 0.8810 - recall: 0.8409 - val_accuracy: 0.8864 - val_loss: 0.2463 - val_precision: 0.8864 - val_recall: 0.8864
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8352 - loss: 0.3960 - precision: 0.8667 - recall: 0.8125 - val_accuracy: 0.7955 - val_loss: 0.3443 - val_precision: 0.7955 - val_recall: 0.7955
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.8977 - loss: 0.3106 - precision: 0.8960 - recall: 0.8807 - val_accuracy: 0.9318 - val_loss: 0.2259 - val_precision: 0.9318 - val_recall: 0.9318
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.8125 - loss: 0.3935 - precision: 0.8443 - recall: 0.8011 - val_accuracy: 0.8409 - val_loss: 0.3670 - val_precision: 0.8409 - val_recall: 0.8409
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8466 - loss: 0.3819 - precision: 0.8683 - recall: 0.8239 - val_accuracy: 0.9091 - val_loss: 0.2654 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.8693 - loss: 0.3537 - precision: 0.8935 - recall: 0.8580 - val_accuracy: 0.8864 - val_loss: 0.2907 - val_precision: 0.8864 - val_recall: 0.8864
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.7841 - loss: 0.5192 - precision: 0.8165 - recall: 0.7330 - val_accuracy: 0.7955 - val_loss: 0.3347 - val_precision: 0.7955 - val_recall: 0.7955
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9205 - loss: 0.2259 - precision: 0.9353 - recall: 0.9034 - val_accuracy: 0.8409 - val_loss: 0.3645 - val_precision: 0.8372 - val_recall: 0.8182
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.8807 - loss: 0.2864 - precision: 0.9059 - recall: 0.8750 - val_accuracy: 0.8409 - val_loss: 0.3115 - val_precision: 0.8409 - val_recall: 0.8409
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9602 - loss: 0.1338 - precision: 0.9655 - recall: 0.9545 - val_accuracy: 0.8636 - val_loss: 0.2272 - val_precision: 0.8837 - val_recall: 0.8636
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9034 - loss: 0.2922 - precision: 0.9064 - recall: 0.8807 - val_accuracy: 0.8182 - val_loss: 0.4167 - val_precision: 0.8182 - val_recall: 0.8182
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.8693 - loss: 0.3086 - precision: 0.9085 - recall: 0.8466 - val_accuracy: 0.8182 - val_loss: 0.5218 - val_precision: 0.8182 - val_recall: 0.8182
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8466 - loss: 0.4051 - precision: 0.8605 - recall: 0.8409 - val_accuracy: 0.9091 - val_loss: 0.2160 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.8352 - loss: 0.4259 - precision: 0.8512 - recall: 0.8125 - val_accuracy: 0.7955 - val_loss: 0.4386 - val_precision: 0.7955 - val_recall: 0.7955
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.8409 - loss: 0.2817 - precision: 0.8970 - recall: 0.8409 - val_accuracy: 0.8864 - val_loss: 0.2378 - val_precision: 0.8837 - val_recall: 0.8636
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.9261 - loss: 0.2159 - precision: 0.9419 - recall: 0.9205 - val_accuracy: 0.9091 - val_loss: 0.2416 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.8977 - loss: 0.3144 - precision: 0.9048 - recall: 0.8636 - val_accuracy: 0.8864 - val_loss: 0.3375 - val_precision: 0.8864 - val_recall: 0.8864
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9489 - loss: 0.1858 - precision: 0.9489 - recall: 0.9489 - val_accuracy: 0.9773 - val_loss: 0.1326 - val_precision: 0.9773 - val_recall: 0.9773
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.8977 - loss: 0.2974 - precision: 0.8960 - recall: 0.8807 - val_accuracy: 0.7500 - val_loss: 0.5945 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8977 - loss: 0.2769 - precision: 0.9023 - recall: 0.8920 - val_accuracy: 0.9091 - val_loss: 0.2148 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.9034 - loss: 0.2678 - precision: 0.9070 - recall: 0.8864 - val_accuracy: 0.7955 - val_loss: 0.4647 - val_precision: 0.7955 - val_recall: 0.7955

# %%
# =========================================
# 8. Plot training and validation loss
# =========================================

plt.figure(figsize=(8, 5))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# =========================================
# 9. Plot training and validation accuracy
# =========================================

plt.figure(figsize=(8, 5))

plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
